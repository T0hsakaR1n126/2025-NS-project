# %%
import pandas as pd
import networkx as nx
import requests
import comtradeapicall
import wbgapi

# %%
import importlib.metadata
version = importlib.metadata.version("comtradeapicall")
print("comtradeapicall version:", version)
# Out:
# comtradeapicall version: 1.3.0

# %%
# comtrade api subscription key (from comtradedeveloper.un.org)
subscription_key = 'e24dfdc3c644425086e31dd6392bca1b'
directory = '<OUTPUT DIR>'  # output directory for downloaded files
proxy_url = '<PROXY URL>'  # optional if you need proxy url

# %%
exportdataframe=pd.DataFrame()
for year in range(2000,2021):
    exportdataframe = pd.concat([exportdataframe,(comtradeapicall.getFinalData(typeCode='C', freqCode='A', clCode='HS', period=str(year),
                                        reporterCode=None, cmdCode='TOTAL', flowCode='X', partnerCode=None,
                                        partner2Code=None,
                                        customsCode=None, motCode=None, maxRecords=None, format_output='JSON',
                                        aggregateBy=None, breakdownMode='classic', countOnly=None, includeDesc=True, subscription_key=subscription_key))],ignore_index=True)

# %%
exportdataframe
# Out:
#        typeCode freqCode  refPeriodId  refYear  refMonth period  reporterCode  \
# 0             C        A     20000101     2000        52   2000             8
# 1             C        A     20000101     2000        52   2000             8
# 2             C        A     20000101     2000        52   2000             8
# 3             C        A     20000101     2000        52   2000             8
# 4             C        A     20000101     2000        52   2000             8
# ...         ...      ...          ...      ...       ...    ...           ...
# 480344        C        A     20200101     2020        52   2020           894
# 480345        C        A     20200101     2020        52   2020           894
# 480346        C        A     20200101     2020        52   2020           894
# 480347        C        A     20200101     2020        52   2020           894
# 480348        C        A     20200101     2020        52   2020           894
#
#        reporterISO reporterDesc flowCode  ... netWgt  isNetWgtEstimated  \
# 0              ALB      Albania        X  ...    NaN              False
# 1              ALB      Albania        X  ...    NaN              False
# 2              ALB      Albania        X  ...    NaN              False
# 3              ALB      Albania        X  ...    NaN              False
# 4              ALB      Albania        X  ...    NaN              False
# ...            ...          ...      ...  ...    ...                ...
# 480344         ZMB       Zambia        X  ...    NaN              False
# 480345         ZMB       Zambia        X  ...    NaN              False
# 480346         ZMB       Zambia        X  ...    NaN              False
# 480347         ZMB       Zambia        X  ...    0.0               True
# 480348         ZMB       Zambia        X  ...    0.0               True
#
#        grossWgt isGrossWgtEstimated  cifvalue      fobvalue  primaryValue  \
# 0           NaN               False       NaN  2.614758e+08  2.614758e+08
# 1           NaN               False       NaN  2.090000e+02  2.090000e+02
# 2           NaN               False       NaN  2.228800e+04  2.228800e+04
# 3           NaN               False       NaN  1.781822e+06  1.781822e+06
# 4           NaN               False       NaN  2.666450e+05  2.666450e+05
# ...         ...                 ...       ...           ...           ...
# 480344      0.0               False       NaN  9.328777e+06  9.328777e+06
# 480345      0.0               False       NaN  5.977954e+07  5.977954e+07
# 480346      0.0               False       NaN  2.330046e+07  2.330046e+07
# 480347      0.0               False       NaN  1.645592e+05  1.645592e+05
# 480348      0.0               False       NaN  3.433489e+05  3.433489e+05
#
#        legacyEstimationFlag isReported  isAggregate
# 0                         0      False        False
# 1                         0      False        False
# 2                         0      False        False
# 3                         0      False        False
# 4                         0      False        False
# ...                     ...        ...          ...
# 480344                    0      False         True
# 480345                    0      False         True
# 480346                    0      False         True
# 480347                    4      False         True
# 480348                    4      False         True
#
# [480349 rows x 47 columns]

# %%
importdataframe=pd.DataFrame()
for year in range(2000,2021):
    importdataframe = pd.concat([importdataframe,(comtradeapicall.getFinalData(typeCode='C', freqCode='A', clCode='HS', period=str(year),
                                        reporterCode=None, cmdCode='TOTAL', flowCode='M', partnerCode=None,
                                        partner2Code=None,
                                        customsCode=None, motCode=None, maxRecords=None, format_output='JSON',
                                        aggregateBy=None, breakdownMode='classic', countOnly=None, includeDesc=True, subscription_key=subscription_key))],ignore_index=True)

# %%
importdataframe
# Out:
#        typeCode freqCode  refPeriodId  refYear  refMonth period  reporterCode  \
# 0             C        A     20000101     2000        52   2000             8
# 1             C        A     20000101     2000        52   2000             8
# 2             C        A     20000101     2000        52   2000             8
# 3             C        A     20000101     2000        52   2000             8
# 4             C        A     20000101     2000        52   2000             8
# ...         ...      ...          ...      ...       ...    ...           ...
# 567097        C        A     20200101     2020        52   2020           894
# 567098        C        A     20200101     2020        52   2020           894
# 567099        C        A     20200101     2020        52   2020           894
# 567100        C        A     20200101     2020        52   2020           894
# 567101        C        A     20200101     2020        52   2020           894
#
#        reporterISO reporterDesc flowCode  ... netWgt  isNetWgtEstimated  \
# 0              ALB      Albania        M  ...    NaN              False
# 1              ALB      Albania        M  ...    NaN              False
# 2              ALB      Albania        M  ...    NaN              False
# 3              ALB      Albania        M  ...    NaN              False
# 4              ALB      Albania        M  ...    NaN              False
# ...            ...          ...      ...  ...    ...                ...
# 567097         ZMB       Zambia        M  ...    NaN              False
# 567098         ZMB       Zambia        M  ...    NaN              False
# 567099         ZMB       Zambia        M  ...    0.0               True
# 567100         ZMB       Zambia        M  ...    0.0               True
# 567101         ZMB       Zambia        M  ...    0.0               True
#
#        grossWgt isGrossWgtEstimated      cifvalue fobvalue  primaryValue  \
# 0           NaN               False  1.089468e+09      NaN  1.089468e+09
# 1           NaN               False  5.660000e+02      NaN  5.660000e+02
# 2           NaN               False  7.847000e+03      NaN  7.847000e+03
# 3           NaN               False  1.625520e+05      NaN  1.625520e+05
# 4           NaN               False  7.769490e+05      NaN  7.769490e+05
# ...         ...                 ...           ...      ...           ...
# 567097      0.0               False  6.865874e+07      NaN  6.865874e+07
# 567098      0.0               False  1.192939e+08      NaN  1.192939e+08
# 567099      0.0               False  3.965430e+03      NaN  3.965430e+03
# 567100      0.0               False  1.405608e+05      NaN  1.405608e+05
# 567101      0.0               False  2.817857e+03      NaN  2.817857e+03
#
#        legacyEstimationFlag isReported  isAggregate
# 0                         0      False        False
# 1                         0      False        False
# 2                         0      False        False
# 3                         0      False        False
# 4                         0      False        False
# ...                     ...        ...          ...
# 567097                    0      False         True
# 567098                    0      False         True
# 567099                    4      False         True
# 567100                    4      False         True
# 567101                    4      False         True
#
# [567102 rows x 47 columns]

# %%
indicator = 'NY.GDP.MKTP.KD'   # GDP (constant 2015 US$)

gdpdataframe = wbgapi.data.DataFrame(
    indicator,
    economy='all',
    time=range(2000, 2021),
)

gdpdataframe = gdpdataframe.reset_index()
gdpdataframe = gdpdataframe.rename(columns={
    'economy': 'iso3c',
    'time': 'year',
    indicator: 'gdp_const_2015_usd'
})

# %%
gdpdataframe
# Out:
#     iso3c        YR2000        YR2001        YR2002        YR2003  \
# 0     ABW  2.545966e+09  2.652439e+09  2.627374e+09  2.656551e+09
# 1     AFE  4.898172e+11  5.069781e+11  5.268371e+11  5.426915e+11
# 2     AFG  6.206548e+09  5.621148e+09  7.228796e+09  7.867263e+09
# 3     AFW  3.266728e+11  3.438188e+11  3.780057e+11  3.992737e+11
# 4     AGO  3.518276e+10  3.666254e+10  4.167273e+10  4.312599e+10
# ..    ...           ...           ...           ...           ...
